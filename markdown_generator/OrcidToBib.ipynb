# %%
orcid = '0009-0007-3716-8076' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)
put_code = put_codes[0]

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    print(work)
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])
# Out:
# {'created-date': {'value': 1759153986547}, 'last-modified-date': {'value': 1765492103497}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0009-0007-3716-8076', 'path': '0009-0007-3716-8076', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Ian Lansdowne'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 193025603, 'path': '/0009-0007-3716-8076/work/193025603', 'title': {'title': {'value': 'Robotic Space Simulator: Controls Implementation for Auxiliary Axes and Zero-G Dynamics'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': '2025 IEEE International Conference on Robotics and Automation (ICRA)'}, 'short-description': None, 'citation': {'citation-type': 'bibtex', 'citation-value': '\n@inproceedings{hilburn_robotic_2025,\n\tlocation = {Atlanta, {GA}, {USA}},\n\ttitle = {Robotic Space Simulator: Controls Implementation for Auxiliary Axes and Zero-G Dynamics},\n\trights = {https://doi.org/10.15223/policy-029},\n\tisbn = {979-8-3315-4139-2},\n\turl = {https://ieeexplore.ieee.org/document/11128455/},\n\tdoi = {10.1109/ICRA55743.2025.11128455},\n\tshorttitle = {Robotic Space Simulator},\n\teventtitle = {2025 {IEEE} International Conference on Robotics and Automation ({ICRA})},\n\tpages = {14624--14630},\n\tbooktitle = {2025 {IEEE} International Conference on Robotics and Automation ({ICRA})},\n\tpublisher = {{IEEE}},\n\tauthor = {Hilburn, Eddie and Pettinger, Adam and Wilkinson, Emily and Lansdowne, Ian and Ambrose, Robert},\n\tdate = {2025-05-19},\n}'}, 'type': 'conference-paper', 'publication-date': {'year': {'value': '2025'}, 'month': {'value': '05'}, 'day': {'value': '19'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1109/icra55743.2025.11128455', 'external-id-normalized': {'value': '10.1109/icra55743.2025.11128455', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1109/icra55743.2025.11128455'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'http://dx.doi.org/10.1109/icra55743.2025.11128455'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Eddie Hilburn'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Adam Pettinger'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Emily Wilkinson'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Ian Lansdowne'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Robert Ambrose'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1759456587428}, 'last-modified-date': {'value': 1759456693542}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0009-0007-3716-8076', 'path': '0009-0007-3716-8076', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Ian Lansdowne'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 193367428, 'path': '/0009-0007-3716-8076/work/193367428', 'title': {'title': {'value': 'TURTLE Quadruped Project (QUAD)'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': ' Texas Regional Robotics Symposium (TEROS)'}, 'short-description': None, 'citation': {'citation-type': 'bibtex', 'citation-value': '@unpublished{lansdowne_turtle_2024,location={College Station, Texas, {USA}},title={{TURTLE} Quadruped Project ({QUAD})},note={Texas Regional Robotics Symposium},author={Lansdowne, Ian and Bucknor-Smartt, Zachary and Dominguez, Oscar and Foltyn, Jonathon and Guttman, Micah and Kannanganat, Shreyas and Kong, Jevine and Parker, Caleb and Silva, Eddy and {et al.}},date={2024-04-30}}\n'}, 'type': 'conference-poster', 'publication-date': {'year': {'value': '2024'}, 'month': {'value': '04'}, 'day': {'value': '30'}}, 'external-ids': {'external-id': None}, 'url': {'value': 'https://teros-texas.github.io/2024/'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Lansdowne, Ian'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Bucknor-Smartt, Zachary'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Dominguez, Oscar'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Foltyn, Jonathon'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Guttman, Micah'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Kannanganat, Shreyas'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Kong, Jevine'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Parker, Caleb'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Silva, Eddy'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}

# %%
with open('proceedings.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')
